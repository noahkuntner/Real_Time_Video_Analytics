# %%
### Create new virtual environment:
    # !python3 -m venv groundup
    # !source groundup/bin/activate   

### Install Ultralytics:
# !pip install ultralytics

##

# %%
from ultralytics import YOLO
# cd /content

# %% [markdown]
# ### Run the Yolo 11n version on the custom dataset and train to understand the safety of workers:

# %%
# !yolo task=detect mode=train model='/Users/noah_/Documents/Development/2024_Projects/GroundUp/yolo11l.pt' data='/Users/noah_/Documents/Development/2024_Projects/GroundUp/construction_site_safety/data.yaml' epochs=50 device='mps'
# Out:
# Ultralytics 8.3.9 🚀 Python-3.11.9 torch-2.4.1 CPU (Apple M1 Max)
# ...

# %%
# !yolo task=detect mode=train model='/Users/noah_/Documents/Development/2024_Projects/GroundUp/yolo11n.pt' data='/Users/noah_/Documents/Development/2024_Projects/GroundUp/construction_site_safety/data.yaml' epochs=20 device='mps'
# Out:
# Ultralytics 8.3.9 🚀 Python-3.11.9 torch-2.4.1 MPS (Apple M1 Max)
# ...
